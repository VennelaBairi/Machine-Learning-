# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
df=pd.read_csv('HR_comma_sep.csv')
# Out:
#      <input type="file" id="files-09167e47-5e4c-45c0-977a-27a17bd368b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09167e47-5e4c-45c0-977a-27a17bd368b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
len(df)
# Out:
# 14999

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
df.sample(n=20)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 13913                0.87             0.90               3
# 5948                 0.74             0.83               4
# 13796                0.91             0.75               2
# 5208                 0.80             0.55               4
# 602                  0.10             0.84               7
# 1865                 0.11             0.93               5
# 12099                0.90             1.00               5
# 8589                 0.78             0.78               3
# 2633                 0.78             0.59               3
# 14949                0.42             0.57               2
# 4626                 0.49             0.79               4
# 11422                0.55             0.58               3
# 1939                 0.10             0.79               7
# 1826                 0.10             0.86               6
# 4242                 0.73             0.91               3
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df.satisfaction_level,df.left,marker='*')

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.Department.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
import seaborn as sb

sb.kdeplot(df[df['left'] == 0]['satisfaction_level'],label='Retained')
sb.kdeplot(df[df['left'] == 1]['satisfaction_level'],label='Left')
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
sb.kdeplot(df[df['left'] == 0]['average_montly_hours'],label='Retained')
sb.kdeplot(df[df['left'] == 1]['average_montly_hours'],label='Left')
# Out:
# <Axes: xlabel='average_montly_hours', ylabel='Density'>

# %%
sb.kdeplot(df[df['left'] == 0]['Work_accident'],label='Retained')
# Out:
# <Axes: xlabel='Work_accident', ylabel='Density'>

# %%
sb.kdeplot(df[df['left'] == 0]['satisfaction_level'],label='Retained')
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
correlation_matrix=df.corr()
sb.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# <ipython-input-14-6cdc13874edb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr()
# <Axes: >

# %%
from scipy.stats import ttest_ind

# Example: T-test for satisfaction level between retained and left employees
retained_satisfaction = df[df['left'] == 0]['satisfaction_level']
left_satisfaction = df[df['left'] == 1]['satisfaction_level']

t_stat, p_value = ttest_ind(retained_satisfaction, left_satisfaction)
t_stat
# Out:
# 51.61280155890104

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Assuming df is your DataFrame
# Separate features and target variable
X = df.drop('left', axis=1)
y = df['left']

# Perform one-hot encoding for categorical variables
X_encoded = pd.get_dummies(X, columns=['Department', 'salary'], drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a Random Forest model
model = RandomForestClassifier()

# Fit the model on the training data
model.fit(X_train, y_train)

# Feature importance
feature_importance = pd.DataFrame({'Feature': X_train.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

# Display the feature importance
print(feature_importance)
# Out:
#                    Feature  Importance
# 0       satisfaction_level    0.303894
# 4       time_spend_company    0.187608
# 2           number_project    0.179737
# 3     average_montly_hours    0.155495
# 1          last_evaluation    0.131615
# 5            Work_accident    0.009749
# 16              salary_low    0.007794
# 15    Department_technical    0.003788
# 17           salary_medium    0.003573
# 13        Department_sales    0.003320
# 14      Department_support    0.002580
# 6    promotion_last_5years    0.001814
# 7         Department_RandD    0.001747
# 8    Department_accounting    0.001645
# 9            Department_hr    0.001579
# 10   Department_management    0.001526
# 11    Department_marketing    0.001345
# 12  Department_product_mng    0.001191

# %%
left=df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained=df[df.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
df.groupby('left').mean()
# Out:
# <ipython-input-22-b0959f325c8f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('left').mean()
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
subdf=df[['satisfaction_level','average_montly_hours','time_spend_company','Work_accident','promotion_last_5years','salary']]
subdf.head()
subdf=pd.DataFrame(subdf)

# %%
subdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   average_montly_hours   14999 non-null  int64
#  2   time_spend_company     14999 non-null  int64
#  3   Work_accident          14999 non-null  int64
#  4   promotion_last_5years  14999 non-null  int64
#  5   salary                 14999 non-null  object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 703.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
subdf.salary=le.fit_transform(subdf.salary)
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  time_spend_company  \
# 0                0.38                   157                   3
# 1                0.80                   262                   6
# 2                0.11                   272                   4
# 3                0.72                   223                   5
# 4                0.37                   159                   3
#
#    Work_accident  promotion_last_5years  salary
# 0              0                      0       1
# 1              0                      0       2
# 2              0                      0       2
# 3              0                      0       1
# 4              0                      0       1

# %%
x=subdf.values
x
# Out:
# array([[3.80e-01, 1.57e+02, 3.00e+00, 0.00e+00, 0.00e+00, 1.00e+00],
#        [8.00e-01, 2.62e+02, 6.00e+00, 0.00e+00, 0.00e+00, 2.00e+00],
#        [1.10e-01, 2.72e+02, 4.00e+00, 0.00e+00, 0.00e+00, 2.00e+00],
#        ...,
#        [3.70e-01, 1.43e+02, 3.00e+00, 0.00e+00, 0.00e+00, 1.00e+00],
#        [1.10e-01, 2.80e+02, 4.00e+00, 0.00e+00, 0.00e+00, 1.00e+00],
#        [3.70e-01, 1.58e+02, 3.00e+00, 0.00e+00, 0.00e+00, 1.00e+00]])

# %%
y=df.left.values
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct=ColumnTransformer([('salary',OneHotEncoder(),[0])],remainder='passthrough')
x=ct.fit_transform(x)
x
# Out:
# <14999x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 61247 stored elements in Compressed Sparse Row format>

# %%
x = x[:, :-1]
x
# Out:
# <14999x95 sparse matrix of type '<class 'numpy.float64'>'
# 	with 47166 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.8871428571428571

# %%
ytest
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
