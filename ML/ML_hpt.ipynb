# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['target']=iris.target
df['flower']=df.target.apply(lambda x: iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target     flower
# ...

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(df.drop(['target', 'flower'], axis='columns'), df['target'], test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.9666666666666667

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
model=SVC()
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.9666666666666667

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(SVC(kernel='linear',C=10),iris.data,iris.target,cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
cross_val_score(SVC(kernel='rbf',C=10),iris.data,iris.target,cv=5)
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.96666667, 1.        ])

# %%
import numpy as np
kernels=['rbf','linear']
Cs=[1,10,20]
gammas=['auto','scale']
avg_scores={}
for kval in kernels:
  for cval in Cs:
    for gval in gammas:
      score=cross_val_score(SVC(kernel=kval,C=cval,gamma=gval),iris.data,iris.target,cv=5)
      avg_scores[kval+'_'+str(cval)+'_'+gval]=np.average(score)

avg_scores
# Out:
# {'rbf_1_auto': 0.9800000000000001,
#  'rbf_1_scale': 0.9666666666666666,
#  'rbf_10_auto': 0.9800000000000001,
#  'rbf_10_scale': 0.9800000000000001,
#  'rbf_20_auto': 0.9666666666666668,
#  'rbf_20_scale': 0.9800000000000001,
#  'linear_1_auto': 0.9800000000000001,
#  'linear_1_scale': 0.9800000000000001,
#  'linear_10_auto': 0.9733333333333334,
#  'linear_10_scale': 0.9733333333333334,
#  'linear_20_auto': 0.9666666666666666,
#  'linear_20_scale': 0.9666666666666666}

# %%
from sklearn.model_selection import GridSearchCV

clf=GridSearchCV(
    SVC(),
    {
        'kernel':['rbf','linear'],
        'C':[1,10,20],
        'gamma':['auto','scale']
    },cv=5,return_train_score=False
)
clf.fit(iris.data,iris.target)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 10, 20], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear']})

# %%
df=pd.DataFrame(clf.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.002189      0.000948         0.001183        0.000067       1
# 1        0.001508      0.000146         0.001040        0.000032       1
# 2        0.002760      0.002105         0.001183        0.000073       1
# 3        0.001548      0.000087         0.000972        0.000042       1
# 4        0.003000      0.002404         0.001143        0.000118      10
# 5        0.001426      0.000049         0.001029        0.000115      10
# 6        0.001686      0.000078         0.001198        0.000256      10
# 7        0.001682      0.000077         0.001003        0.000056      10
# 8        0.001682      0.000044         0.001081        0.000052      20
# 9        0.001419      0.000047         0.000949        0.000051      20
# 10       0.001547      0.000077         0.000983        0.000056      20
# 11       0.003659      0.002840         0.001154        0.000107      20
#
# ...

# %%
df[['params','mean_test_score']]
# Out:
#                                              params  mean_test_score
# 0        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}         0.980000
# 1     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}         0.980000
# 2       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}         0.966667
# 3    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}         0.980000
# 4       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}         0.980000
# 5    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}         0.973333
# 6      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}         0.980000
# 7   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}         0.973333
# 8       {'C': 20, 'gamma': 'auto', 'kernel': 'rbf'}         0.966667
# 9    {'C': 20, 'gamma': 'auto', 'kernel': 'linear'}         0.966667
# 10     {'C': 20, 'gamma': 'scale', 'kernel': 'rbf'}         0.980000
# 11  {'C': 20, 'gamma': 'scale', 'kernel': 'linear'}         0.966667

# %%
dir(clf)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_estimator_type',
#  '_format_results',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_required_parameters',
#  '_run_search',
#  '_select_best_index',
#  '_validate_data',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
# ...

# %%
clf.best_estimator_
# Out:
# SVC(C=1, gamma='auto')

# %%
clf.best_params_
# Out:
# {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
from sklearn.model_selection import RandomizedSearchCV
rs=RandomizedSearchCV(
    SVC(),
    {
        'kernel':['rbf','linear'],
        'C':[1,10,20],
        'gamma':['auto','scale']
    },cv=5,return_train_score=False,n_iter=2
)
rs.fit(iris.data,iris.target)
df=pd.DataFrame(rs.cv_results_)[['param_C','param_kernel','param_gamma','mean_test_score']]
df
# Out:
#   param_C param_kernel param_gamma  mean_test_score
# 0      10          rbf        auto             0.98
# 1       1       linear       scale             0.98
